# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitheesh2001/NLP/blob/main/Trasnformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import GPT2Tokenizer,GPT2LMHeadModel

# %%
tokenizer=GPT2Tokenizer.from_pretrained('gpt2-large')
model=GPT2LMHeadModel.from_pretrained('gpt2-large',pad_token_id=tokenizer.eos_token_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
tokenizer.eos_token_id
# Out:
# 50256

# %%
tokenizer.decode(tokenizer.eos_token_id)
# Out:
# '<|endoftext|>'

# %%
sentence='i love watching motivation movies'
numeric_ids=tokenizer.encode(sentence,return_tensors='pt')

# %%
numeric_ids
# Out:
# tensor([[   72,  1842,  4964, 14052,  6918]])

# %%
tokenizer.decode(numeric_ids[0][4])
# Out:
# ' movies'

# %%
result=model.generate(numeric_ids,max_length=50,num_beams=5,no_repeat_ngram_size=2,early_stopping=True)
result
# Out:
# tensor([[   72,  1842,  4964, 14052,  6918,    11,   290,   428,   530,   318,
#            645,  6631,    13,   198,   198,   464,  2646,  5679,   257,  1448,
#            286,  2460,   355,   484, 21030,   319,   257,  2975,  5296,  1973,
#            262,  1578,  1829,   287,  2989,   286,   257,   649,  1363,    13,
#            383,  2646,   318,  5901,   351,   617,   286,   262, 36090,  6386]])

# %%
tokenizer.decode(result[0],skip_special_tokens=True)
# Out:
# 'i love watching motivation movies, and this one is no exception.\n\nThe film follows a group of friends as they embark on a road trip across the United States in search of a new home. The film is filled with some of the funniest'
